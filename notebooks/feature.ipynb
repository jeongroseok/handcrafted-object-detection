# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

DATA_PATH = "data.csv"

# %%
df = pd.read_csv("../data.csv", index_col="id")
df
# Out:
#                object    area   perimeter
# id
# 0                 pen  5525.0  577.126978
# 1                 pen  5524.5  577.712765
# 2                 pen  5521.5  577.854900
# 3                 pen  5531.5  577.854900
# 4                 pen  5116.0  527.137083
# ..                ...     ...         ...
# 124  iphone_converter   526.5  100.811182
# 125  iphone_converter   555.0  102.970562
# 126  iphone_converter   611.0  109.254833
# 127  iphone_converter   601.5  109.840620
# 128  iphone_converter   538.0  103.941125
#
# [125 rows x 3 columns]

# %%
df['formfactor'] = (4*np.pi*df['area']) / (df['perimeter'] ** 2)

# %%
plt.scatter(df['perimeter'], df['area'])
